# %% [markdown]
# By [Yulandy Chiu](https://www.youtube.com/@YulandySpace)
#
# Aided with Gemini/Claude/ChatGPT and modified by Yulandy Chiu
#
# Version: 2025/01/25
#
# Videos:
# * [Python實作AI代理系統 Agentic System: 評估器-優化器 工作流程 Evaluator-optimizer Workflow 生成合規文件 | Step-by-Step 做中學！](https://youtu.be/dgC3wyASDiY)
#
# Facebook: [Yulandy Chiu的AI資訊站](https://www.facebook.com/yulandychiu)
#
#  This code is licensed under the Creative Commons Attribution-NonCommercial 4.0
#  International License (CC BY-NC 4.0). You are free to use, modify, and share this code for non-commercial purposes, provided you give appropriate credit. For more details, see the LICENSE file or visit: https://creativecommons.org/licenses/by-nc/4.0/
#  © [2025] [Yulandy Chiu](https://www.youtube.com/@YulandySpace)

# %%
import google.generativeai as genai
from google.colab import userdata
import time
from typing import Dict, List, Tuple


# 初始化 Gemini
api_key = userdata.get('Gemini_API_Key')
genai.configure(api_key=api_key)
model = genai.GenerativeModel("gemini-1.5-flash")



def generate_content(topic: str, previous_feedback: str = None, previous_content: str = None) -> str:
        """使用 Gemini 生成內容"""
        try:
            # 根據是否有之前的反饋構建提示
            if previous_feedback:
                full_prompt = f"""
                主題: {topic}

                原始文章: {previous_content}

                反饋: {previous_feedback}

                請根據主題、原始文章、反饋，生成一篇改進後的文章。
                """
            else:
                full_prompt = f"""
                請針對以下主題生成一篇內容充實的文章:
                {topic}

                要求:
                1. 語言要清晰易懂
                2. 結構要完整
                3. 大約使用450個tokens
                """
            # 英文：tokens= 單詞數量 × 1.2
            # 中文：tokens= 字數 × 1.5


            response = model.generate_content(full_prompt)
            return response.text

        except Exception as e:
            print(f"生成內容時發生錯誤: {str(e)}")
            return ""


#  feedback extraction 建議文字擷取
def extract_feedback_method(response_text):
    try:
        lines = response_text.split('\n')
        collect_feedback = False
        feedback_lines = []

        for line in lines:
            if '建議:' in line:
                collect_feedback = True
                # 如果 "建議:" 後面還有文字，加入第一行
                first_line = line.split('建議:')[1].strip()
                if first_line:
                    feedback_lines.append(first_line)
                continue

            if collect_feedback:
                feedback_lines.append(line.strip())

        return '\n'.join(feedback_lines).strip()
    except Exception as e:
        print(f"提取建議時發生錯誤: {str(e)}")
        return None





def evaluate_content(content: str, rubric: str) -> Tuple[float, str]:
        """使用 Gemini 評估內容質量"""
        try:  #根據topic修改對應rubric
            evaluation_prompt = f"""
            請評估以下文章的質量，並提供具體的改進建議。

            文章內容:
            {content}

            請提供:
            1. 質量評分（0-1的小數，其中1代表最好）。
            2. 詳細的改進建議

            評分標準:
            {rubric}

            回覆格式:
            分數: [數字]
            建議: [僅根據評分標準，提供具體建議]
            """

            response = model.generate_content(evaluation_prompt)
            response_text = response.text


            # 解析回覆以提取分數和建議
            try:
                score_line = [line for line in response_text.split('\n') if '分數:' in line][0]
                score = float(score_line.split(':')[1].strip())
                feedback = extract_feedback_method(response_text)

                return (score, feedback)
            except:
                # 如果解析失敗，返回預設值
                return (0.7, "無法解析評估結果，請重試")

        except Exception as e:
            print(f"評估內容時發生錯誤: {str(e)}")
            return (0.5, "評估過程發生錯誤")




import google.generativeai as genai
from google.colab import userdata
import time
from typing import Dict, List, Tuple


# 初始化 Gemini
api_key = userdata.get('Gemini_API_Key')
genai.configure(api_key=api_key)
model = genai.GenerativeModel("gemini-1.5-flash")



def generate_content(topic: str, previous_feedback: str = None, previous_content: str = None) -> str:
        """使用 Gemini 生成內容"""
        try:
            # 根據是否有之前的反饋構建提示
            if previous_feedback:
                full_prompt = f"""
                主題: {topic}

                原始文章: {previous_content}

                反饋: {previous_feedback}

                請根據主題、原始文章、反饋，生成一篇改進後的文章。
                """
            else:
                full_prompt = f"""
                請針對以下主題生成一篇內容充實的文章:
                {topic}

                要求:
                1. 語言要清晰易懂
                2. 結構要完整
                3. 大約使用450個tokens
                """
            # 英文：tokens= 單詞數量 × 1.2
            # 中文：tokens= 字數 × 1.5


            response = model.generate_content(full_prompt)
            return response.text

        except Exception as e:
            print(f"生成內容時發生錯誤: {str(e)}")
            return ""


#  feedback extraction 建議文字擷取
def extract_feedback_method(response_text):
    try:
        lines = response_text.split('\n')
        collect_feedback = False
        feedback_lines = []

        for line in lines:
            if '建議:' in line:
                collect_feedback = True
                # 如果 "建議:" 後面還有文字，加入第一行
                first_line = line.split('建議:')[1].strip()
                if first_line:
                    feedback_lines.append(first_line)
                continue

            if collect_feedback:
                feedback_lines.append(line.strip())

        return '\n'.join(feedback_lines).strip()
    except Exception as e:
        print(f"提取建議時發生錯誤: {str(e)}")
        return None





def evaluate_content(content: str, rubric: str) -> Tuple[float, str]:
        """使用 Gemini 評估內容質量"""
        try:  #根據topic修改對應rubric
            evaluation_prompt = f"""
            請評估以下文章的質量，並提供具體的改進建議。

            文章內容:
            {content}

            請提供:
            1. 質量評分（0-1的小數，其中1代表最好）。
            2. 詳細的改進建議

            評分標準:
            {rubric}

            回覆格式:
            分數: [數字]
            建議: [僅根據評分標準，提供具體建議]
            """

            response = model.generate_content(evaluation_prompt)
            response_text = response.text


            # 解析回覆以提取分數和建議
            try:
                score_line = [line for line in response_text.split('\n') if '分數:' in line][0]
                score = float(score_line.split(':')[1].strip())
                feedback = extract_feedback_method(response_text)

                return (score, feedback)
            except:
                # 如果解析失敗，返回預設值
                return (0.7, "無法解析評估結果，請重試")

        except Exception as e:
            print(f"評估內容時發生錯誤: {str(e)}")
            return (0.5, "評估過程發生錯誤")





# 迭代參數設定
def optimize_article(topic: str, rubric: str, target_score: float = 0.9, max_iterations: int = 3) -> Dict:
        """主要優化循環"""
        iteration_history = []
        current_content = generate_content(topic)

        for i in range(max_iterations):
            print(f"\n當前內容 (迭代 {i+1}):")
            print(current_content)

            # 評估當前內容
            score, feedback = evaluate_content(current_content,rubric)
            iteration_history.append({
                "iteration": i + 1,
                "content": current_content,
                "score": score,
                "feedback": feedback
            })

            print(f"\n評估結果 (迭代 {i+1}):")
            print(f"評分: {score}")
            print(f"反饋: {feedback}")

            # 如果達到目標分數，退出循環
            if score >= target_score:
                print("\n已達到目標質量！")
                break

            # 加入延遲以避免觸發API限制
            time.sleep(5)

            # 根據反饋生成改進的內容
            previous_content = current_content
            current_content = generate_content(topic, feedback, previous_content)

        return {
            "final_content": current_content,
            "final_score": score,
            "iterations": iteration_history
        }




topic = "如何達到工作和生活平衡?"
# 關鍵步驟，rubric必須明確，才能透過迭代提升生成品質
rubric = "20%，有提供生活案例，本項得滿分；20%，文章具吸引力，本項得滿分；20%，有考慮目標讀者，本項得滿分；40%，有可衡量的目標和具體步驟，本項得滿分。"
target_score=0.80
max_iterations=5


result = optimize_article(topic,rubric,target_score,max_iterations)


print(f"主題: {topic}")
print("\n最終結果:")
print("最終分數:", result["final_score"])
print("\n最終內容:")
print(result["final_content"])
# Out:
# 當前內容 (迭代 1):
# 如何達到工作和生活平衡？這是一個許多人都在苦苦追尋的答案，卻又沒有標準答案的問題。因為「平衡」本身就帶有主觀性，它並非一種狀態，而是一種持續調整和努力的過程。  找到適合自己的平衡點，需要深入了解自身需求，並積極採取策略。
#
# 首先，釐清個人價值觀至關重要。你重視什麼？是事業成功、家庭和睦、個人成長，還是其他？  一旦明白自己的優先順序，就能更有效地分配時間和精力。例如，如果你重視家庭，那麼下班後就應該盡量把時間留給家人，而不是加班到深夜。  這並非意味著要放棄事業，而是要找到更有效的時間管理方法，在有限的時間內完成工作，並確保有足夠的時間陪伴家人。
#
# 有效的時間管理技巧是關鍵。  學會使用時間管理工具，例如待辦事項清單、時間阻斷法（Pomodoro Technique）、GTD（Getting Things Done）等，可以幫助你更有效率地完成工作，避免時間被瑣事吞噬。  同時，要學會說「不」，拒絕不必要的任務或邀請，才能騰出時間給真正重要的事情。  優先處理重要且緊急的事情，將不太緊急的事情安排在空閒時間處理，可以避免手忙腳亂，提升效率。
#
# 除了時間管理，設定界限也非常重要。  明確工作和生活的界限，例如下班後關閉工作郵件和訊息通知，避免工作侵占私人時間。  創造一個專屬於自己的私人空間，讓你在下班後能夠完全放鬆身心，遠離工作的壓力。  這可以是閱讀、運動、聽音樂，甚至是簡單的冥想，任何能讓你放鬆身心的活動都可以。
#
# 此外，注重身心健康也是不可或缺的。  充足的睡眠、均衡的飲食和規律的運動，可以提升你的工作效率和生活品質。  壓力過大會影響身心健康，因此要學會管理壓力，例如通過深呼吸、瑜伽或其他減壓方式來釋放壓力。  尋求朋友、家人或專業人士的支持，也可以幫助你更好地應對壓力。
#
# 最後，要記住，工作和生活平衡不是一蹴而就的，而是一個持續調整的過程。  你需要不斷地反思和調整自己的策略，找到最適合自己的平衡點。  不要追求完美，允許自己犯錯，並從錯誤中學習，不斷地完善自己的工作和生活方式。  只有這樣，才能在工作和生活中找到屬於自己的幸福和滿足。
#
#
# 評估結果 (迭代 1):
# 評分: 0.6
# 反饋: 這篇文章整體而言寫得不錯，論述清晰，建議也合理，但缺乏具體的生活案例和可衡量的目標，以及對目標讀者的考慮不夠深入，因此評分較低。
#
# **1. 有提供生活案例 (20%):  0/20**
#
# 文章完全沒有提供任何具體的生活案例。例如，可以加入一個案例，說明一個人在應用時間阻斷法後，如何有效率地完成工作，並騰出時間陪伴家人。  或者，描述一個人在設定界限後，如何減少工作對私人生活的干擾，並感受到生活品質的提升。  這些具體的例子能讓讀者更易於理解和應用文中提到的方法。
#
#
# **2. 文章具吸引力 (20%): 10/20**
#
# 文章開頭點明主題，並指出「平衡」是一個持續調整的過程，這抓住了讀者的痛點，有一定的吸引力。然而，文章整體敘述較為平鋪直敘，缺乏更生動的語言和引人入勝的表達方式，可以提升吸引力。
#
#
# **3. 有考慮目標讀者 (20%): 10/20**
#
# 文章沒有明確指出目標讀者是誰。文章內容適合廣泛的讀者群體，但如果能更明確地針對特定讀者（例如，職場新人、高壓工作的管理者等），可以調整內容和用詞，使其更具針對性和說服力。  例如，針對職場新人的文章，可以更著重於時間管理和界限設定的技巧；而針對高壓工作者的文章，則可以更強調壓力管理和身心健康的策略。
#
#
# **4. 有可衡量的目標和具體步驟 (40%): 20/40**
#
# 文章提供了許多建議，但缺乏可衡量的目標和具體步驟。例如，「有效的時間管理技巧」部分，雖然提到了工具和方法，但沒有說明如何具體地應用這些工具和方法，也沒有提供可衡量的目標，例如「每周減少加班時間2小時」。  每個建議都應該包含可衡量的目標和具體的步驟，讓讀者可以實際操作並追蹤進度，例如：
#
# * **目標：** 下班後減少工作郵件的查看次數。
# * **步驟：**  1. 設定工作郵箱通知關閉時間。2.  下班後將工作郵件標記為“稍後處理”。3.  指定特定時間段處理工作郵件，例如早上上班前 30 分鐘。
# * **衡量指標：**  記錄每天下班後查看工作郵件的次數，並追蹤每周的平均值。
#
# 文章需要在每個建議中加入類似這樣的目標、步驟和衡量指標，才能讓讀者有更清晰的操作指南。
#
# 當前內容 (迭代 2):
# ## 如何達到工作和生活平衡：一份實用指南
#
# 許多人渴望工作和生活平衡，卻苦尋不得。  事實上，「平衡」並非一成不變的狀態，而是一場持續調整的旅程。  這篇文章將提供實用的策略和步驟，幫助你找到屬於自己的平衡點，無論你是職場新鮮人，還是經驗豐富的管理者。
#
# **案例一：小麗的「番茄工作法」之旅**
#
# 小麗，一位剛入職的市場行銷專員，經常加班到深夜，身心俱疲。  她試著應用番茄工作法（Pomodoro Technique）：25分鐘專注工作，5分鐘休息。  起初，她很難集中注意力，經常超時。  但她堅持記錄每次工作時間和完成的工作量，逐漸調整番茄時間和休息時間的長度，並學習在休息時間徹底遠離工作，例如散步或聽音樂。  幾個月後，小麗不僅完成了工作，還擁有更多時間陪伴家人和朋友，生活品質明顯提升。  她的衡量指標是：每周加班時間從10小時減少到2小時，工作效率提升了30%。
#
#
# **1. 釐清你的核心價值觀：你的優先順序是什麼？**
#
# 你重視什麼？事業成功、家庭和睦、個人成長、健康還是其他？  寫下你的核心價值觀，並根據重要性排序。  這將成為你分配時間和精力的指南。  例如，如果你重視家庭，那麼下班後就應該盡量把時間留給家人。  這並不意味著放棄事業，而是要找到更有效率的工作方式。
#
# **2.  有效的時間管理：制定可衡量的目標並採取行動**
#
# **目標：** 每周減少加班時間2小時。
#
# **步驟：**
#
# * **使用時間管理工具：**  例如待辦事項清單 (Todoist, Any.do)，GTD方法，或番茄工作法。  記錄每日工作時間和完成的任務，追踪你的效率。
# * **學會說「不」：** 拒絕不必要的任務或邀請，保護你的時間。
# * **優先處理重要且緊急的事情：**  使用艾森豪威爾矩陣（重要性/緊急性矩陣）來分類任務。
#
#
# **衡量指標：**  每周記錄實際工作時間和加班時間，並與目標進行比較。
#
#
# **3. 設定清晰的界限：工作和生活的分隔線**
#
# **目標：** 下班後減少工作郵件的查看次數。
#
# **步驟：**
#
# 1. 設定工作郵箱通知關閉時間 (例如晚上7點至早上8點)。
# 2. 下班後將工作郵件標記為“稍後處理”。
# 3. 指定特定時間段處理工作郵件，例如早上上班前 30 分鐘。
#
# **衡量指標：**  記錄每天下班後查看工作郵件的次數，並追蹤每周的平均值。  目標是將次數降至最低。
#
#
# **4. 注重身心健康：為你的身心充電**
#
# **目標：** 每周至少進行3次，每次至少30分鐘的運動。
#
# **步驟：**
#
# * **充足的睡眠：**  保證每天至少7-8小時的睡眠時間。
# * **均衡的飲食：**  攝取營養豐富的食物。
# * **規律的運動：**  選擇你喜歡的運動方式，例如瑜伽、跑步、游泳等。
# * **壓力管理：**  學習深呼吸、冥想等減壓技巧。
#
# **衡量指標：**  記錄每周運動時間和睡眠時間。
#
#
# **5. 持續調整與反思：平衡是一個持續的過程**
#
# 工作和生活平衡不是一蹴而就的，你需要不斷反思和調整策略。  記錄你的進度，找出哪些方法有效，哪些需要改进。  允許自己犯錯，並從錯誤中學習，不斷完善你的工作和生活方式。
#
#
# 記住，找到屬於你的平衡點，是一個個人化的旅程。  沒有完美的答案，只有最適合你的方法。  開始行動，持續調整，你將在工作和生活中找到屬於你的幸福和滿足。
#
#
# 評估結果 (迭代 2):
# 評分: 0.8
# 反饋: 這篇文章結構清晰，提供了實用的建議，並以小麗的案例作開端，吸引讀者閱讀。  也考慮到不同階段的讀者(職場新鮮人到管理者)，並提供了可衡量的目標和步驟，這部分做得相當不錯。  但仍有一些地方可以改進，以達到滿分：
#
#
# 1. **提高可衡量目標和具體步驟的完整性 (增加40%評分)：** 目前提供的目標和步驟雖然具體，但缺乏深度和多樣性。  以「有效的時間管理」為例，只提供了待辦事項清單、GTD、番茄工作法等工具，以及「學會說不」和「優先處理重要且緊急的事情」等建議，缺乏更細緻的指導。  可以考慮：
#
# * **時間管理工具的深入說明：**  不要只是列舉工具名稱，可以簡要說明每種工具的優缺點和使用方法，並針對不同個性的人群，推薦合適的工具。 例如，對於容易分心的人，可以詳細說明番茄工作法的具體操作步驟以及如何克服其局限性。 對於喜歡規劃的人，可以介紹GTD方法的具體步驟。
# * **「學會說不」的技巧：**  如何優雅而有效地拒絕他人請求，需要更具體的技巧和示例。 可以提供一些實用的句型和應對策略。
# * **艾森豪威爾矩陣的應用實例：**  提供一個實際任務分類的例子，幫助讀者更好地理解如何運用該矩陣。
# * **更多時間管理策略：**  除了列舉的工具和方法，可以加入其他有效的时间管理策略，例如時間區塊法 (Time Blocking)、二八法則 (Pareto Principle) 等，并解释其适用场景。
#
#
# 2. **增强案例的說服力 (增加20%評分)：** 小麗的案例雖然不錯，但可以更深入地描述她遇到的具體挑戰，以及如何克服這些挑戰，並更詳細地說明如何調整番茄工作法，例如她最初的番茄時間和休息時間設定是多少，如何逐步調整到適合自己的時間比例，以及她如何克服在休息時間難以完全放鬆工作的問題。  更詳細的描述將使案例更具說服力。  可以加入更多數據支持，例如完成任務數量、工作質量方面的提升等。
#
# 3. **提升文章的吸引力 (增加20%評分)：**  文章整體比較平鋪直敘，可以加入一些更生動的語言和修辭手法，例如使用更具吸引力的標題、更活潑的語氣，以及更豐富的案例或數據支持。  可以考虑在各部分加入一些提问，引导读者思考。
#
#
# 通过以上改进，文章的质量可以进一步提升，更有效地帮助读者找到属于自己的工作与生活平衡。
#
# 已達到目標質量！
# 主題: 如何達到工作和生活平衡?
#
# 最終結果:
# 最終分數: 0.8
#
# 最終內容:
# ## 如何達到工作和生活平衡：一份實用指南
#
# 許多人渴望工作和生活平衡，卻苦尋不得。  事實上，「平衡」並非一成不變的狀態，而是一場持續調整的旅程。  這篇文章將提供實用的策略和步驟，幫助你找到屬於自己的平衡點，無論你是職場新鮮人，還是經驗豐富的管理者。
#
# **案例一：小麗的「番茄工作法」之旅**
#
# 小麗，一位剛入職的市場行銷專員，經常加班到深夜，身心俱疲。  她試著應用番茄工作法（Pomodoro Technique）：25分鐘專注工作，5分鐘休息。  起初，她很難集中注意力，經常超時。  但她堅持記錄每次工作時間和完成的工作量，逐漸調整番茄時間和休息時間的長度，並學習在休息時間徹底遠離工作，例如散步或聽音樂。  幾個月後，小麗不僅完成了工作，還擁有更多時間陪伴家人和朋友，生活品質明顯提升。  她的衡量指標是：每周加班時間從10小時減少到2小時，工作效率提升了30%。
#
#
# **1. 釐清你的核心價值觀：你的優先順序是什麼？**
#
# 你重視什麼？事業成功、家庭和睦、個人成長、健康還是其他？  寫下你的核心價值觀，並根據重要性排序。  這將成為你分配時間和精力的指南。  例如，如果你重視家庭，那麼下班後就應該盡量把時間留給家人。  這並不意味著放棄事業，而是要找到更有效率的工作方式。
#
# **2.  有效的時間管理：制定可衡量的目標並採取行動**
#
# **目標：** 每周減少加班時間2小時。
#
# **步驟：**
#
# * **使用時間管理工具：**  例如待辦事項清單 (Todoist, Any.do)，GTD方法，或番茄工作法。  記錄每日工作時間和完成的任務，追踪你的效率。
# * **學會說「不」：** 拒絕不必要的任務或邀請，保護你的時間。
# * **優先處理重要且緊急的事情：**  使用艾森豪威爾矩陣（重要性/緊急性矩陣）來分類任務。
#
#
# **衡量指標：**  每周記錄實際工作時間和加班時間，並與目標進行比較。
#
#
# **3. 設定清晰的界限：工作和生活的分隔線**
#
# **目標：** 下班後減少工作郵件的查看次數。
#
# **步驟：**
#
# 1. 設定工作郵箱通知關閉時間 (例如晚上7點至早上8點)。
# 2. 下班後將工作郵件標記為“稍後處理”。
# 3. 指定特定時間段處理工作郵件，例如早上上班前 30 分鐘。
#
# **衡量指標：**  記錄每天下班後查看工作郵件的次數，並追蹤每周的平均值。  目標是將次數降至最低。
#
#
# **4. 注重身心健康：為你的身心充電**
#
# **目標：** 每周至少進行3次，每次至少30分鐘的運動。
#
# **步驟：**
#
# * **充足的睡眠：**  保證每天至少7-8小時的睡眠時間。
# * **均衡的飲食：**  攝取營養豐富的食物。
# * **規律的運動：**  選擇你喜歡的運動方式，例如瑜伽、跑步、游泳等。
# * **壓力管理：**  學習深呼吸、冥想等減壓技巧。
#
# **衡量指標：**  記錄每周運動時間和睡眠時間。
#
#
# **5. 持續調整與反思：平衡是一個持續的過程**
#
# 工作和生活平衡不是一蹴而就的，你需要不斷反思和調整策略。  記錄你的進度，找出哪些方法有效，哪些需要改进。  允許自己犯錯，並從錯誤中學習，不斷完善你的工作和生活方式。
#
#
# 記住，找到屬於你的平衡點，是一個個人化的旅程。  沒有完美的答案，只有最適合你的方法。  開始行動，持續調整，你將在工作和生活中找到屬於你的幸福和滿足。
